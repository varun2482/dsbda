# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.drop('deck',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
Q1_male=df[df['sex']=='male']['age'].quantile(.25)
Q3_male=df[df['sex']=='male']['age'].quantile(.75)

print(Q1_male)
print(Q3_male)
# Out:
# 21.0
# 39.0

# %%
Q1_female=df[df['sex']=='female']['age'].quantile(.25)
Q3_female=df[df['sex']=='female']['age'].quantile(.75)

print(Q1_female)
print(Q3_female)
# Out:
# 18.0
# 37.0

# %%
Q1_male_survived=df[((df['sex']=='male') & (df['survived']==1))]['age'].quantile(.25)
Q3_male_survived=df[((df['sex']=='male') & (df['survived']==1))]['age'].quantile(.75)

print(Q1_male_survived)
print(Q3_male_survived)
# Out:
# 18.0
# 36.0

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='age',y='sex')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df['age'].quantile(.25)
# Out:
# 20.125

# %%
df['age'].quantile(.75)
# Out:
# 38.0

# %%
sns.violinplot(data=df,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(data=df,x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(data=df,x='sex',y='age',hue='survived',split=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(10,7))
sns.stripplot(data=df,x='sex',y='age',hue='survived',size=7)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(data=df,x='sex',y='age',hue='survived',size=7)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize=(10,7))
sns.swarmplot(data=df,x='sex',y='age',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.subplot(1,2,1)
sns.histplot(data=df,x='sepal_length')

plt.subplot(1,2,2)
sns.histplot(data=df,x='sepal_width')
plt.show()

plt.figure(figsize=(5,5))
plt.subplot(2,2,1)
sns.histplot(data=df,x='petal_length')

plt.subplot(2,2,2)
sns.histplot(data=df,x='petal_width')
plt.show()

# %%
sns.pairplot(data=df,hue='species')

# %%
plt.figure(figsize=(15,7))
sns.violinplot(data=df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,7))
sns.swarmplot(data=df)
# Out:
# <Axes: >

# %%
sns.kdeplot(data=df)
# Out:
# <Axes: ylabel='Density'>
