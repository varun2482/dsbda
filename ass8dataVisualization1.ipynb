# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.scatterplot(data=df,x='age',y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data=df,x='age',y='fare',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.histplot(data=df,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='age',hue='pclass',bins=10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='age',hue='pclass',bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='age',hue='sex',bins=10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.displot(data=df,x='age',col='embark_town',bins=10)

# %%
sns.barplot(data=df,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(data=df,x='sex',y='age',ci=None)
# Out:
# <ipython-input-18-dc178ba9b3a1>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x='sex',y='age',ci=None)
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(data=df,x='embark_town',y='pclass')
# Out:
# <Axes: xlabel='embark_town', ylabel='pclass'>

# %%
sns.barplot(data=df,x='pclass',y='fare',hue='embarked')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.countplot(data=df,x='pclass',hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=df,x='pclass')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.catplot(data=df,x='embark_town',kind='count')

# %%
sns.catplot(data=df,x='embark_town',col='pclass',kind='count')
